# %% [markdown]
# # 文献调研
# 除了本目录所在的3篇文章（和步态有关的），还有以下文章，建议通读
# - `/home/hac/isaac/AnyMani/source/anymani/mytask/AnyRotate/Yang 等 - 2024 - AnyRotate Gravity-Invariant In-Hand Object Rotation with Sim-to-Real Touch.pdf`
# - `/home/hac/isaac/AnyMani/source/anymani/mytask/RMA/Qi 等 - 2022 - In-Hand Object Rotation via Rapid Motor Adaptation.pdf`
# - `/home/hac/isaac/AnyMani/source/anymani/mytask/AnyRotate/Liu 等 - 2025 - DexNDM Closing the Reality Gap for Dexterous In-Hand Rotation via Joint-Wise Neural Dynamics Model.pdf`，这个读前10页即可，后面附录过长
# - `/home/hac/isaac/get_zero/docs/Patel和Song - 2024 - GET-Zero Graph Embodiment Transformer for Zero-shot Embodiment Generalization.pdf`
#
# 以下虽然不是手内操作，但其注意力机制的图网络很有趣
# - `TRO-Grasp/doc/Fei 等 - 2025 - T(R,O) Grasp Efficient Graph Diffusion of Robot-Object Spatial Transformation for Cross-Embodiment.pdf`

# %% [markdown]
# ## 个人暴论
# 经过实验经历，像手内旋转、重定向这样接触密集型的手内操作任务，只适用于在关节空间的自回归类策略（即输出单时间步动作而非动作轨迹）进行，不适用任务空间以及扩散策略这样的action chunk策略
